# %% [markdown]
# <a href="https://colab.research.google.com/github/deansaco/825/blob/main/AlexNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q -U keras_tuner
# Out:
#      |████████████████████████████████| 98 kB 5.0 MB/s

# %%
import os
import pickle
import math
import random
import csv
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
import keras_tuner as kt
from sklearn.utils import shuffle
from tensorflow.keras.layers import Dense, Conv2D, Dropout, ReLU, MaxPool2D, Flatten, BatchNormalization


print('All modules imported.')
# Out:
# All modules imported.

# %%
#mount zip file for google colab gpu use
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/gdrive', force_remount=True)

# Location of Zip File
drive_path = '/gdrive/MyDrive/Traffic-Sign-Classifier-master.zip'
local_path = '/content'

# Copy the zip file and move it up one level (AKA out of the drive folder)
# !cp '{drive_path}' .

# Navigate to the copied file and unzip it quietly
os.chdir(local_path)
# !unzip -q 'Traffic-Sign-Classifier-master.zip'
# Out:
# Mounted at /gdrive

# %%
#add regulization loss to the model!!!!

# %% [markdown]
# # 1 Reload the preprocessed data

# %%
# 1 Reload the preprocessed data

pickle_file = '/content/Traffic-Sign-Classifier-master/traffic-signs-data/pre-data.pickle'
with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train = pickle_data['train_features']
    y_train = pickle_data['train_labels']
    X_valid = pickle_data['valid_features']
    y_valid = pickle_data['valid_labels']
    X_test = pickle_data['test_features']
    y_test = pickle_data['test_labels']
    signnames = pickle_data['signnames']
    del pickle_data  # Free up memory
    
# Shuffle the data set
X_train, y_train = shuffle(X_train, y_train)
X_valid, y_valid = shuffle(X_valid, y_valid)
X_test, y_test = shuffle(X_test, y_test)

X_train=X_train/255.0
X_valid=X_valid/255.0
X_test=X_test/255.0

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
print(len(signnames))
print('Data loaded.')
# Out:
# (34799, 32, 32, 3) (34799,)
# (4410, 32, 32, 3) (4410,)
# (12630, 32, 32, 3) (12630,)
# 43
# Data loaded.

# %%
# #convert output into one hot encoded vector
y_train = tf.one_hot(y_train, 43)
y_valid = tf.one_hot(y_valid, 43)
y_test = tf.one_hot(y_test, 43)

# %%
plt.figure(figsize=(12,12))
# plot first few images
for i in range(25):
    # define subplot
    plt.subplot(5, 5, i+1)
    # plot raw pixel data
    plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
# show the figure
plt.show()

# %%
def create_model(hp):
    AlexNet= tf.keras.Sequential(layers=[Conv2D(9,5, activation= ReLU()), 
                            BatchNormalization(),
                            MaxPool2D([2, 2], [2, 2]),
                            BatchNormalization(),
                            Conv2D(32,3, activation= ReLU()),
                            BatchNormalization(),
                            MaxPool2D([2, 2], [2, 2]),
                            BatchNormalization(),
                            Conv2D(48,3, activation= ReLU(), padding='same'),
                            BatchNormalization(),
                            Conv2D(64,3, activation= ReLU(), padding='same'),
                            BatchNormalization(),
                            Conv2D(96,3, activation= ReLU(), padding ='same'),
                            BatchNormalization(),
                            MaxPool2D([2, 2], [2, 2]),
                            BatchNormalization(),
                            Flatten(),
                            Dense(400, activation= ReLU()),
                            Dropout(0.5),
                            Dense(160, activation= ReLU()),
                            Dropout(0.5),
                            Dense(43)
                           ])

    hp_learning_rate=hp.Choice('learning_rate', values=[1e-3, 1e-4, 1e-5])
# Layer 1: Input = 32x32x3. Output = 28x28x9.
# Convolutional. 
# filters (number of output filters) = 9, 
# kernel size (height and width of conv window 5x5) =5, activation function = relu

# Max Pooling. Input = 28x28x9. Output = 14x14x9.
# pool size = 2x2 window, strides = moves 2 in x and 2 in y for each pool step

# Layer 2: Input = 14x14x9. Output = 12x12x32.
# Convolutional. filters = 32, kernel_size=3

# Max Pooling. Input = 12x12x32. Output = 6x6x32.

# Layer 3: Input = 6x6x32. Output = 6x6x48.
# Convolutional. filters = 48, kernel_size=3

# Layer 4: Input = 6x6x48. Output = 6x6x64.
# Convolutional. filters = 64, kernel_size=3

# Layer 5: Input = 6x6x64. Output = 6x6x96.
# Convolutional. filters = 96, kernel_size=3

# Max Pooling. Input = 6x6x96. Output = 3x3x96.

# Flatten. Input = 3x3x96. Output = 864.

# Layer 6: Input = 864. Output = 400.
# Dense: Fully Connected. 
# Dropout: disconnect 50% of connections to prevent overfitting

# Layer 6: Input = 400. Output = 160.
# Dense: Fully Connected. 
# Dropout: disconnect 50% of connections to prevent overfitting

# Layer 6: Input = 160. Output = 43.
# Dense: Fully Connected.     
# optimizer = tf.train.GradientDescentOptimizer(learning_rate = LEARNING_RATE)
# Adam optimizer
    
    opt = tf.keras.optimizers.Adam(learning_rate=hp_learning_rate, name='Adam')
    loss_function=tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    AlexNet.compile(optimizer=opt,loss=loss_function, metrics=['acc'])
    
    return AlexNet

# %%
tuner =kt.Hyperband(create_model,
                    objective='val_acc',
                    max_epochs = 40)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(X_train, y_train, validation_data=(X_test, y_test), epochs=50, callbacks=[stop_early])

best_hps= tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal learning rate for the optimizer is
{best_hps.get('learning_rate')}.
""")
# Out:
# Trial 3 Complete [00h 00m 29s]
# val_acc: 0.9348376989364624
#
# Best val_acc So Far: 0.9348376989364624
# Total elapsed time: 00h 01m 56s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal learning rate for the optimizer is
# 0.001.

# %%
model=tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, 
                         epochs=50, 
                         batch_size=128, 
                         validation_data=(X_test, y_test))

val_acc_per_epoch = history.history['val_acc']
best_epoch=val_acc_per_epoch.index(max(val_acc_per_epoch))+1
print('Best epoch: %d'% (best_epoch,))
# Out:
# Epoch 1/50
# 272/272 [==============================] - 11s 26ms/step - loss: 1.5399 - acc: 0.5707 - val_loss: 1.6159 - val_acc: 0.5430
# Epoch 2/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.2926 - acc: 0.9095 - val_loss: 0.3066 - val_acc: 0.9044
# Epoch 3/50
# 272/272 [==============================] - 5s 18ms/step - loss: 0.1360 - acc: 0.9596 - val_loss: 0.2910 - val_acc: 0.9199
# Epoch 4/50
# 272/272 [==============================] - 5s 18ms/step - loss: 0.0867 - acc: 0.9732 - val_loss: 0.3022 - val_acc: 0.9247
# Epoch 5/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0651 - acc: 0.9797 - val_loss: 0.3144 - val_acc: 0.9219
# Epoch 6/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0607 - acc: 0.9816 - val_loss: 0.2845 - val_acc: 0.9337
# Epoch 7/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0439 - acc: 0.9864 - val_loss: 0.2574 - val_acc: 0.9427
# Epoch 8/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0438 - acc: 0.9871 - val_loss: 0.2847 - val_acc: 0.9355
# Epoch 9/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0381 - acc: 0.9891 - val_loss: 0.2659 - val_acc: 0.9402
# Epoch 10/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0340 - acc: 0.9898 - val_loss: 0.2315 - val_acc: 0.9500
# Epoch 11/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0363 - acc: 0.9897 - val_loss: 0.2922 - val_acc: 0.9451
# Epoch 12/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0335 - acc: 0.9900 - val_loss: 0.2878 - val_acc: 0.9394
# Epoch 13/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0317 - acc: 0.9909 - val_loss: 0.3746 - val_acc: 0.9253
# Epoch 14/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0292 - acc: 0.9909 - val_loss: 0.2676 - val_acc: 0.9485
# Epoch 15/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0333 - acc: 0.9898 - val_loss: 0.2836 - val_acc: 0.9423
# Epoch 16/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0328 - acc: 0.9911 - val_loss: 0.2454 - val_acc: 0.9534
# Epoch 17/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0250 - acc: 0.9930 - val_loss: 0.2567 - val_acc: 0.9495
# Epoch 18/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0291 - acc: 0.9921 - val_loss: 0.2279 - val_acc: 0.9543
# Epoch 19/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0177 - acc: 0.9946 - val_loss: 0.2690 - val_acc: 0.9520
# Epoch 20/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0255 - acc: 0.9933 - val_loss: 0.2884 - val_acc: 0.9482
# Epoch 21/50
# 272/272 [==============================] - 6s 22ms/step - loss: 0.0194 - acc: 0.9945 - val_loss: 0.2977 - val_acc: 0.9492
# Epoch 22/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0256 - acc: 0.9934 - val_loss: 0.2886 - val_acc: 0.9477
# Epoch 23/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0273 - acc: 0.9929 - val_loss: 0.3104 - val_acc: 0.9477
# Epoch 24/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0199 - acc: 0.9944 - val_loss: 0.3002 - val_acc: 0.9457
# Epoch 25/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0234 - acc: 0.9937 - val_loss: 0.3169 - val_acc: 0.9520
# Epoch 26/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0194 - acc: 0.9945 - val_loss: 0.2680 - val_acc: 0.9542
# Epoch 27/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0195 - acc: 0.9945 - val_loss: 0.3327 - val_acc: 0.9453
# Epoch 28/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0248 - acc: 0.9935 - val_loss: 0.2340 - val_acc: 0.9582
# Epoch 29/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0142 - acc: 0.9962 - val_loss: 0.2453 - val_acc: 0.9609
# Epoch 30/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0166 - acc: 0.9958 - val_loss: 0.5453 - val_acc: 0.9395
# Epoch 31/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0209 - acc: 0.9946 - val_loss: 0.2428 - val_acc: 0.9591
# Epoch 32/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0173 - acc: 0.9957 - val_loss: 0.3537 - val_acc: 0.9450
# Epoch 33/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0114 - acc: 0.9968 - val_loss: 0.2832 - val_acc: 0.9606
# Epoch 34/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0181 - acc: 0.9949 - val_loss: 0.3076 - val_acc: 0.9555
# Epoch 35/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0128 - acc: 0.9969 - val_loss: 0.3828 - val_acc: 0.9508
# Epoch 36/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0199 - acc: 0.9948 - val_loss: 0.3440 - val_acc: 0.9528
# Epoch 37/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0147 - acc: 0.9960 - val_loss: 0.3540 - val_acc: 0.9532
# Epoch 38/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0173 - acc: 0.9959 - val_loss: 0.2492 - val_acc: 0.9601
# Epoch 39/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0152 - acc: 0.9963 - val_loss: 0.2933 - val_acc: 0.9496
# Epoch 40/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0152 - acc: 0.9961 - val_loss: 0.2845 - val_acc: 0.9592
# Epoch 41/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0206 - acc: 0.9952 - val_loss: 0.2834 - val_acc: 0.9579
# Epoch 42/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0130 - acc: 0.9968 - val_loss: 0.2631 - val_acc: 0.9602
# Epoch 43/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0150 - acc: 0.9965 - val_loss: 0.3190 - val_acc: 0.9557
# Epoch 44/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0099 - acc: 0.9977 - val_loss: 0.2772 - val_acc: 0.9565
# Epoch 45/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0134 - acc: 0.9968 - val_loss: 0.2857 - val_acc: 0.9571
# Epoch 46/50
# 272/272 [==============================] - 5s 20ms/step - loss: 0.0098 - acc: 0.9976 - val_loss: 0.2464 - val_acc: 0.9630
# Epoch 47/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0181 - acc: 0.9955 - val_loss: 0.3336 - val_acc: 0.9504
# Epoch 48/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0128 - acc: 0.9968 - val_loss: 0.2766 - val_acc: 0.9553
# Epoch 49/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0098 - acc: 0.9974 - val_loss: 0.3166 - val_acc: 0.9573
# Epoch 50/50
# 272/272 [==============================] - 5s 17ms/step - loss: 0.0139 - acc: 0.9968 - val_loss: 0.2795 - val_acc: 0.9608
# Best epoch: 46

# %%
plt.plot(history.history['acc'], label='train_accuracy')
plt.plot(history.history['val_acc'], label = 'test_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

#evaluate model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)

      
print(f'Test Accuracy:', 100*test_accuracy)
# Out:
# 395/395 - 2s - loss: 0.2795 - acc: 0.9608 - 2s/epoch - 5ms/step
# Test Accuracy: 96.08076214790344

# %%
#hypermodel.load_weights(checkpoint_path)
test_loss, test_accuracy = model.evaluate(X_test, y_test)
valid_loss, valid_accuracy = model.evaluate(X_valid, y_valid)
train_loss, train_accuracy =model.evaluate(X_train, y_train)


print("restored model, test accuracy: {:5.2f}%".format(100*test_accuracy))
print("restored model, validation accuracy: {:5.2f}%".format(100*valid_accuracy))

print("restored model, train accuracy: {:5.2f}%".format(100*train_accuracy))
# Out:
# 395/395 [==============================] - 2s 6ms/step - loss: 0.2795 - acc: 0.9608
# 138/138 [==============================] - 1s 6ms/step - loss: 0.2754 - acc: 0.9707
# 1088/1088 [==============================] - 6s 6ms/step - loss: 2.9264e-04 - acc: 0.9999
# restored model, test accuracy: 96.08%
# restored model, validation accuracy: 97.07%
# restored model, train accuracy: 99.99%

# %%
for i in range(1,10):
    test_image = X_test[i]
    array=np.expand_dims(test_image, axis=0)
    prediction = model.predict(array)
    prediction= (np.argmax(prediction))
    print("predicted sign:", signnames[prediction])    
    test_label= y_test[i]
    arr=np.expand_dims(test_label, axis=0)
    truth= (np.argmax(arr))
    plt.figure(figsize=(12,12))
    # define subplot
    plt.subplot(5, 5, i+1)
    # plot raw pixel data
    plt.imshow(test_image, cmap=plt.get_cmap('gray'))
    # show the figure
    plt.show()
    print("real sign:", signnames[truth])
    print('\n')
    print('\n')
# Out:
# predicted sign: No vehicles
# real sign: No vehicles
#
#
#
#
# predicted sign: Priority road
# real sign: Priority road
#
#
#
#
# predicted sign: Speed limit (30km/h)
# real sign: Speed limit (30km/h)
#
#
#
#
# predicted sign: Speed limit (50km/h)
# real sign: Speed limit (50km/h)
#
#
#
#
# predicted sign: Slippery road
# real sign: Slippery road
#
#
#
#
# predicted sign: Yield
# real sign: Yield
#
#
#
#
# predicted sign: Speed limit (50km/h)
# real sign: Speed limit (50km/h)
#
#
#
#
# predicted sign: Speed limit (60km/h)
# real sign: Speed limit (60km/h)
#
#
#
#
# predicted sign: Keep right
# real sign: Keep right

# %%
accuracys = [train_accuracy, valid_accuracy, test_accuracy]
tick_labels = ["training set", "validation set", "testing set"]
plt.bar(range(3), accuracys)
plt.xlabel('data set')
plt.ylabel('accuracy')
plt.xticks(range(3), tick_labels)
for x_,y_ in zip(range(3), accuracys):
    plt.text(x_ - 0.1, y_, '%.3f'%y_)
plt.show()
